# %%
a=str(input("enter the colors: "))
b=str(input("enter colors: "))
colors=a-b
print("the colors are: ",colors)
# Out:
# enter the colors:  red yellow blue green
# enter colors:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 a=str(input("enter the colors: "))
#       2 b=str(input("enter colors: "))
# ----> 3 colors=a-b
#       4 print("the colors are: ",colors)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
#print colors in set1 but not in set2
a=set(input("enter the colors: ").split())
b=set(input("enter colors: ").split())
colors=a-b
print("the colors are: ",colors)
# Out:
# enter the colors:  red yellow green blue
# enter colors:  white red
# the colors are:  {'green', 'blue', 'yellow'}

# %%
#union of colors from 2 set
a=set(input("enter the colors: ").split())
b=set(input("enter colors: ").split())
colors=a|b # | represent union
print("the colors are: ",colors)
# Out:
# enter the colors:  red yellow blue
# enter colors:  white
# the colors are:  {'white', 'red', 'blue', 'yellow'}
