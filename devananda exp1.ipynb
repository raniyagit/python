# %%
C=float(input("enter a temperature in celcius"))
F=T(C*9/5)+32
print("temparature in fahrenheit:",F)
# Out:
# enter a temperature in celcius35
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 C=float(input("enter a temperature in celcius"))
# ----> 2 F=T(C*9/5)+32
#       3 print("temparature in fahrenheit:",F)
#
# NameError: name 'T' is not defined

# %%
C=float(input("enter a temperature in celcius"))
F=(C*9/5)+32
print("temparature in fahrenheit:",F)
# Out:
# enter a temperature in celcius35
# temparature in fahrenheit: 95.0

# %%
K=float(input("enter distance in kilometer"))
M=K*0.62137
print("kilometers in miles:",M)
# Out:
# enter distance in kilometer1
# kilometers in miles: 0.62137

# %%
K=float(input("enter distance in kilometer"))
M=K*0.62137
print("kilometers in miles:",M)
# Out:
# enter distance in kilometer45.2
# kilometers in miles: 28.085924000000002

# %%
#area of a circle
import math
r=int(input("enter the radius of a circle:"))
area=round(math.pi*r*r,2)
print("area of a circle is:",area)
# Out:
# enter the radius of a circle:5
# area of a circle is: 78.54
