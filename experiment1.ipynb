# %%
c=float(input("enter a temperature in celcius"))
f=(c*9//5)+32
print("temperature in fahrenheit: ",f)
# Out:
# enter a temperature in celcius 45.9
# temperature in fahrenheit:  114.0

# %%
k=float(input("enter distance in kilometers"))
m=round(k*0.62137)
print("kilometers in miles: ",m)
# Out:
# enter distance in kilometers 69.5
# kilometers in miles:  43

# %%
#compte n+nn+nnn=?
n=int(input("enter the values of n: "))
nn=n+n
nnn=n+n+n
sum=int(n)+int(nn)+int(nnn)
print(n,"+",nn,"+",nnn,"=",sum)
# Out:
# enter the values of n:  5
# 5 + 10 + 15 = 30

# %%
#area of circle
import math
r=float(input("enter the radius= "))
area=math.pi*r*r
print(round(area,2))
# Out:
# enter the radius=  3
# 28.27

# %%
#biggest of number
a=int(input("enter the first no: "))
b=int(input("enter the second number: "))
c=int(input("enter the third number: "))
l=max(a,b,c)
print("max= ",l)
# Out:
# enter the first no:  4
# enter the second number:  8
# enter the third number:  5
# max=  8
