# %%
#change the string
string=input("enter the string: ")
new_string=string[-1]+string[1:-1]+string[0]
print("new string: ",new_string)
# Out:
# enter the string:  raniya
# new string:  aaniyr

# %%
#string made of 1st and last 2 charecters
string=input("enter a string: ")
new=string[:2]+string[-2:]
print("new string: ",new)
# Out:
# enter a string:  helloguyss
# new string:  hess

# %%
#string sep with space by swapping the charecter
s1=input("enter first string: ")
s2=input("enter second string: ")
new_s1=s2[0]+s1[1:]
new_s2=s1[0]+s2[1:]
print(new_s1+" "+new_s2)
# Out:
# enter first string:  ranniya
# enter second string:  good
# ganniya rood

# %%
#string from given string($)
string=input("enter a string: ")
new=string[0]+string[1:].replace(string[0],'$')
print("new string: ",new)
# Out:
# enter a string:  cocacola
# new string:  co$a$ola
